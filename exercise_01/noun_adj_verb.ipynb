# %%
#Write a program that creates gramatically valid English sentences.
#Here, we consider a sentence to be gramatically correct when it follows the simple English grammar of the form:
#Article Adjective Noun Verb. That is, even the sentence A insect fly. is, for the moment, considered correct.
#Create additionally to the exercise above, a list of definite and indefinite articles and verbs from an online resource.
#Extend the above program to generate all possible sentences with the given words.

nouns = ['time','year', 'people', 'woman','life','child', 'world', 'student', 'group', 'country']

adjectives = ['other', 'new', 'good', 'different', 'long', 'little', 'important', 'political', 'white', 'real']

verbs = ['be', 'have', 'do', 'say', 'would', 'make', 'know', 'think', 'take','see']




sentences = {(adjective, noun, verb) for adjective in adjectives for noun in nouns for verb in verbs}


for sentence in sentences:
    print(sentence)
print(len(sentences))
# Out:
# ('different', 'woman', 'do')
# ('important', 'country', 'would')
# ('little', 'world', 'take')
# ('long', 'time', 'be')
# ('long', 'life', 'know')
# ('good', 'country', 'make')
# ('other', 'woman', 'do')
# ('real', 'people', 'make')
# ('real', 'life', 'know')
# ('little', 'year', 'be')
# ('white', 'woman', 'would')
# ('good', 'people', 'have')
# ('important', 'people', 'take')
# ('long', 'life', 'do')
# ('good', 'life', 'take')
# ('long', 'year', 'be')
# ('little', 'woman', 'see')
# ('political', 'country', 'know')
# ('white', 'time', 'take')
# ('important', 'group', 'see')
# ('long', 'child', 'think')
# ('long', 'woman', 'have')
# ('different', 'country', 'think')
# ('political', 'group', 'have')
# ('different', 'child', 'make')
# ('real', 'child', 'think')
# ('real', 'woman', 'have')
# ('political', 'country', 'do')
# ('political', 'people', 'take')
# ('other', 'country', 'think')
# ('important', 'world', 'say')
# ('good', 'child', 'know')
# ('good', 'time', 'say')
# ...
